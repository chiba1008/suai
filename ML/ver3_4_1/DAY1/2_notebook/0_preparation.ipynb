# %% [markdown]
# ## 事前準備のお願い
# - こちらのNotebookがすべてエラーなく実行できれば事前準備はOKです
# - 実行するときは，実行したい部分（セル）をクリックした後にShiftキーとEnterキーを同時押し

# %% [markdown]
# *  仮想環境起動時に長文のエラーが表示されることがありますが、気にしなくてOKです
# *  最後に(仮想環境名) C:\...のように表示されていれば、仮想環境は正常に起動しています
# *  kerasやtensorflowのインポート時にnumpyに関する警告が出る場合がありますが、演習には支障ないため、気にしなくてOKです

# %% [markdown]
# ### (1) 各ライブラリのバージョン確認

# %%
import numpy as np
print(np.__version__)
print("1.21.6であればok")

import pandas as pd
print(pd.__version__)
print("1.3.5であればok")

import sklearn as sk
print(sk.__version__)
print("0.20.3であればok")

import matplotlib as mpl
print(mpl.__version__)
print("3.0.3であればok")

import seaborn as sns
print(sns.__version__)
print("0.9であればok")


import PIL as pil
print(pil.__version__)
print("5.4.1であればok")
# Out:
# 1.21.6
# 1.21.6であればok
# 1.3.5
# 1.3.5であればok
# 0.20.3
# 0.20.3であればok
# 3.0.3
# 3.0.3であればok
# 0.9.0
# 0.9であればok
# 5.4.1
# 5.4.1であればok

# %%
import tensorflow as tf
print(tf.__version__)
print("1.14.0であればok")
# Out:
# /Users/suhara/opt/anaconda3/envs/kouza_ML/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/suhara/opt/anaconda3/envs/kouza_ML/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/suhara/opt/anaconda3/envs/kouza_ML/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import keras
keras.__version__
print(keras.__version__)
print("2.2.4であればok")
# Out:
# 2.2.4
# 2.2.4であればok
# Using TensorFlow backend.

# %%
import graphviz
print(graphviz.__version__)
print("0.11であればok")

from pydotplus import version as pdp
print(pdp.__version__)
print("2.0.2であればok")
# Out:
# 0.11
# 0.11であればok
# 2.0.2
# 2.0.2であればok

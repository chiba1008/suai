# %% [markdown]
# #  活性化関数

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## ステップ関数

# %%
def step(x):
    return np.array(x>0).astype(np.int)
    
x = np.arange(-5,5,0.1)
y = step(x) 
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-0.1,1.1])
plt.show()
# Out:
# /var/folders/_0/2_dvy_6971dfbf9qw0p9q7lm0000gn/T/ipykernel_13020/432092495.py:2: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return np.array(x>0).astype(np.int)

# %% [markdown]
# ## シグモイド関数

# %%
def sigmoid(x):
    return 1 / (1+ np.exp(-x))

x = np.arange(-5,5,0.1)
y = sigmoid(x) 
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-0.1,1.1])
plt.show()

# %% [markdown]
# ## tanh関数

# %%
def tanh(x):
    return np.tanh(x)

x = np.arange(-5,5,0.1)
y = tanh(x) 
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-2,2])
plt.show()

# %% [markdown]
# ### [演習]
# - 以下のReLU関数を完成させましょう

# %% [markdown]
# ## ReLU関数
# - $\mathrm{ReLU(x)} = \max{(x, 0)}$
# - $x$が0以上ならそのまま，0未満なら0と出力する

# %%
def relu(x):
    return np.maximum(0,x)

x = np.arange(-5,5,0.1)
y = relu(x) 
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-5.0,5])
plt.show()

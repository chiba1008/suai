# %% [markdown]
# ## 学習済みモデルを使って画像を識別する
#
# 使用する学習済みモデル:Inception-v3
# https://arxiv.org/pdf/1512.00567.pdf
#
# 学習済みモデルの利用方法：
# https://github.com/tensorflow/models/blob/v1.13.0/tutorials/image/imagenet/classify_image.py
#
# 1000クラスの内訳
# https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a

# %%
from PIL import Image

# %%
# 画像の確認
img = Image.open("../1_data/bridge.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %% [markdown]
# ### 識別の実行

# %%
# !python classify_image.py --image_file "../1_data/bridge.jpg"
# Out:
# Traceback (most recent call last):
#   File "/Users/chibakeigo/Developer/SUAI/ML/ver3_4_1/DAY4/2_notebook/classify_image.py", line 227, in <module>
#     tf.app.run(main=main, argv=[sys.argv[0]] + unparsed)
# AttributeError: module 'tensorflow' has no attribute 'app'

# %%
# 画像の確認
img = Image.open("../1_data/park.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x250>

# %% [markdown]
# ### 識別の実行

# %%
# !python classify_image.py --image_file "../1_data/park.jpg"
# Out:
# Traceback (most recent call last):
#   File "/Users/chibakeigo/Developer/SUAI/ML/ver3_4_1/DAY4/2_notebook/classify_image.py", line 227, in <module>
#     tf.app.run(main=main, argv=[sys.argv[0]] + unparsed)
# AttributeError: module 'tensorflow' has no attribute 'app'

# %% [markdown]
# ### [問]
# * 上記の画像にて、人が認識されないのはなぜでしょうか？
#
# ### [演習]
# - 自分が持っている写真をいくつか読みこんで、識別させてみましょう。
# - 識別されやすい物体と識別されにくい物体を確認してみましょう。

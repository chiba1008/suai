# %% [markdown]
# #  活性化関数

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 恒等写像関数
# $h(x)=x$

# %%
def linear(x):
    return x
    
x = np.arange(-5,5,0.1)
y = linear(x) 
plt.figure(figsize=(3.5,3))
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-5,5])
plt.show()

# %% [markdown]
# ### [演習]
# - 以下のステップ関数、シグモイド関数、tanh関数、ReLU関数、LeakyReLU関数、Softplus関数、Hardtanh関数を完成させましょう。

# %% [markdown]
# ## ステップ関数

# %%
# ヒント
a = np.array([-1,0,1])
print(a > 0)
np.array([True, False]).astype(np.int64)
# Out:
# [False False  True]
# array([1, 0])

# %%
def step(x):
    return np.array(x>0).astype(np.int64)
    
x = np.arange(-5,5,0.1)
y = step(x) 
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-0.1,1.1])
plt.show()

# %% [markdown]
# ## シグモイド関数

# %% [markdown]
# $\displaystyle{h(x)=\frac{1}{(1+\exp(-x))}}$

# %%
# ヒント
np.exp(1)
# Out:
# 2.718281828459045

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

x = np.arange(-5,5,0.1)
y = sigmoid(x) 
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-0.1,1.1])
plt.show()

# %% [markdown]
# ## tanh関数

# %% [markdown]
# $\displaystyle h(x) = \tanh(x) = \frac{\sinh(x)}{\cosh(x)}=\frac{e^x-e^{-x}}{e^x+e^{-x}}$

# %%
# ヒント
np.sinh(1),np.cosh(1),np.tanh(1)
# Out:
# (1.1752011936438014, 1.5430806348152437, 0.7615941559557649)

# %%
def tanh(x):
    return np.tanh(x)

x = np.arange(-5,5,0.1)
y = tanh(x) 
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-2,2])
plt.show()

# %% [markdown]
# ## ReLU関数

# %% [markdown]
# $h(x) = x (x>=0)$
# $h(x) = 0 (x<0)$

# %%
# ヒント
np.maximum(1, np.array([-1, 0, 1, 2]))
# Out:
# array([1, 1, 1, 2])

# %%
def relu(x):
    return np.maximum(0,x)

x = np.arange(-5,5,0.1)
y = relu(x) 
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-5.0,5])
plt.show()

# %% [markdown]
# ## LeakyReLU
# $h(x) = x (x>=0)$
# $h(x) = ax (x<0)$

# %%
def leakyrelu(x, a=0.1):
    return np.maximum(0, x) + np.minimum(0,x)*a

x = np.arange(-5,5,0.1)
y = leakyrelu(x) 
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-5.0,5])
plt.show()

# %% [markdown]
# ## Softplus
# $h(x)=\log(1+\exp(x))$

# %%
def softplus(x):
    return np.log(1+np.exp(x))

x = np.arange(-5,5,0.1)
y = softplus(x) 
plt.figure(figsize=(3.5,3))
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-5.0,5])
plt.show()

# %% [markdown]
# ## Hardtanh
# $h(x) = x (-1<=x, x<=1)$
# $h(x) = 1 (x>1)$
# $h(x) = -1 (x<-1)$

# %%
def hardtanh(x):
    return np.maximum(-1, np.minimum(1, x))

x = np.arange(-5,5,0.1)
y = hardtanh(x) 
plt.figure(figsize=(3.5,3))
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-5.0,5])
plt.show()
